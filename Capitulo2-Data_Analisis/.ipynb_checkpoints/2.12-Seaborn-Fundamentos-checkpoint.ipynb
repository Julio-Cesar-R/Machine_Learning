# %% [markdown]
# <center><u><H1>Seaborn Basics</H1></u></center>

# %% [markdown]
# ## Seaborn Installation:
# - pip install seaborn
# - conda install seaborn

# %%
#Libreria seaborn superior a matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Load the data

# %%
iris_ = pd.read_csv("../data/iris_dataset.csv")
iris_.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth        Class
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ## Load the data with Seaborn

# %%
#cargar informacion con Seaborn
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#violinplot con seaborn
sns.violinplot(x = "sepal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %% [markdown]
# ## Styling in Seaborn: Contexts

# %%
#Estilos
# Styles: darkgrid, whitegrid, dark, white, and ticks
sns.set_style("darkgrid")
sns.boxplot(x="species", y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# ## Grids in Seaborn

# %%
#Grid o fondo
sns.set_style("whitegrid")
sns.boxplot(x="species", y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
#Formato del grid
sns.set_style("white")
sns.boxplot(x="species", y="petal_length", data=iris)
sns.despine()

# %%
#Formato 
sns.set_style("whitegrid")
sns.boxplot(x="species", y="petal_length", data=iris)
sns.despine(left=True, bottom=True)

# %% [markdown]
# ## set_context and set

# %%
#Estilos de la grafica
# Available contexts are: paper, notebook, talk and poster
sns.set_style("ticks")
sns.set_context("paper")
sns.boxplot(x="species", y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
#Estilo "poster"
sns.set_style("ticks")
sns.set_context("poster")
sns.boxplot(x="species", y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
#Estilos
sns.set_style("whitegrid")
sns.set_context("poster", font_scale = .5, rc={"grid.linewidth": 0.6})
sns.boxplot(x="species", y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
#Estilos
#You can also pass more arguments to set_context() 
sns.set_context("paper", font_scale=1.8, rc={"font.size":5,"axes.labelsize":1.0})
sns.boxplot(x="species", y="petal_length", data=iris, palette="husl")
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
# Reset default params
sns.set(rc={"font.size":6,"axes.labelsize":6})
sns.boxplot(x="species", y="petal_length", data=iris, palette="husl")
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
# Reset default params
sns.set(palette='Set2')
sns.set_context("notebook")
sns.boxplot(x="species", y="petal_length", data=iris)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
#Parametros que podrmos cambiar
sns.plotting_context()
# Out:
# {'font.size': 12.0,
#  'axes.labelsize': 12.0,
#  'axes.titlesize': 12.0,
#  'xtick.labelsize': 11.0,
#  'ytick.labelsize': 11.0,
#  'legend.fontsize': 11.0,
#  'axes.linewidth': 1.25,
#  'grid.linewidth': 1.0,
#  'lines.linewidth': 1.5,
#  'lines.markersize': 6.0,
#  'patch.linewidth': 1.0,
#  'xtick.major.width': 1.25,
#  'ytick.major.width': 1.25,
#  'xtick.minor.width': 1.0,
#  'ytick.minor.width': 1.0,
#  'xtick.major.size': 6.0,
#  'ytick.major.size': 6.0,
#  'xtick.minor.size': 4.0,
#  'ytick.minor.size': 4.0,
#  'legend.title_fontsize': 12.0}

# %% [markdown]
# ## How To Set The Figure Size in Seaborn

# %%
#cambiar el tamaño del grafico con "ax"
#Grafico de dispercion
fig, ax = plt.subplots(figsize=(10,4))
sns.stripplot(x="species", y="petal_length", data=iris, ax=ax)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %%
#Tamaño del grafico con seaborn catplot
sns.catplot(x="species", y="petal_length", data=iris, kind="bar", height=5, aspect=2, palette="muted", legend=False)

# %% [markdown]
# ## How To Rotate Label Text in Seaborn

# %%
#Rotar los labels "g.set_xticklabels(rotation=90)"
sns.set_context("poster",font_scale = .5,)
g = sns.catplot(x="species", y="petal_length", data=iris, kind="bar", height=4, aspect=2, palette="Paired")
g.set_xticklabels(rotation=90)

# %% [markdown]
# ## Setting xlim or ylim in Seaborn

# %%
# limite de valores en el eje de las y "g.set(ylim=(0, 12))"
g = sns.catplot(x="species", y="petal_length", data=iris, kind="bar", height=4, aspect=2, palette="Set2", legend=False)
g.set_xticklabels(rotation=90)
g.set(ylim=(0, 12)) # alternative you can use : ax.set_ylim(0,10)

# %% [markdown]
# ## Adding a Title

# %%
#Agregar titulo
b = sns.boxplot(x="species", y="petal_length", data=iris, palette="muted")
b.set_title('Bar graph for species')
# Out:
# Text(0.5, 1.0, 'Bar graph for species')

# %% [markdown]
# ## References:
# - https://seaborn.pydata.org/installing.html
#
# - https://seaborn.pydata.org/
#
# - https://seaborn.pydata.org/generated/seaborn.color_palette.html
#
# - https://seaborn.pydata.org/tutorial/color_palettes.html
