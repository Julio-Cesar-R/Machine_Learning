# %% [markdown]
# <center><u><H1>Gráficos Estadísticos con Matplotlib</H1></u></center>

# %%
#Librerias
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## <u>Scatter:</u>

# %%
#Grafica con plt.scatter
x = np.linspace(-10,10,50)
y = x**2
plt.scatter(x,y, s=200, color='red',marker='.',edgecolors='black')

# %% [markdown]
# ## <u>Bar Chart:</u>

# %%
#Diagrama de barras
classes = ['C1', 'C2', 'C3', 'C4']
colors  = ['#FF5733', '#3533FF', '#33FF5D', '#FDFF33']
numerical = [[10, 15, 5, 7],
             [1, 3, 4, 9],
             [4, 15, 8, 10],
             [7, 6, 13, 8]]

number_groups = len(classes) 
bin_width = 0.2

fig, ax = plt.subplots(figsize=(8,6))

for i in range(number_groups):
    ax.bar(x=np.arange(len(classes)) + i*bin_width, 
           height=numerical[i],
           width=bin_width,
           color=colors[i],
           align='center')

ax.set_xticks(np.arange(len(classes)) + 0.4)
ax.set_xticklabels(classes)
ax.legend(classes, facecolor='w', loc='best')

# %% [markdown]
# ## <u>Histogram:</u>

# %%
#Histograma
x = np.random.sample(50)
n, bins, patches = plt.hist(x, bins=20, facecolor='orange', alpha=0.7, density=True)
plt.setp(patches[3], 'facecolor', 'b')
plt.xlabel('bins')
plt.ylabel('Values')
plt.grid(color='grey', linestyle='-', linewidth=0.25, alpha=0.5)

# %% [markdown]
# n: is the number of counts in each bin of the histogram
#
# bins: is the left hand edge of each bin
#
# patches: is the individual patches used to create the histogram, e.g a collection of rectangles

# %% [markdown]
# ## <u>Pie Chart:</u>

# %%
# Pie chart, where the slices are ordered and plotted counter-clockwise:
labels = 'Segment 1', 'Segment 2', 'Segment 3', 'Segment 4'
sizes = [30, 35, 25, 10]  # percentages, the sum of all of them must to be 100%
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Segment 2')

fig, ax = plt.subplots()
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
# Out:
# (-1.1144509022638318,
#  1.1312382101451997,
#  -1.2210697990242716,
#  1.1057652336712287)

# %% [markdown]
# ## <u>Box Plot:</u>

# %% [markdown]
# * Q3: This is the 75th percentile value (upper hinge) of the data.
# * Q3: This is the 25th percentile value (lower hinge) of the data.
# * Box: It is a difference between the upper hinge and the lower hinge.
# * Median: This is the midpoint of the data.
# * Max: This is the upper inner fence. It is 1.5 times the step above Q3.
# * Min: This is the lower inner fence. It is 1.5 times the step below Q1.
# * Any value that is greater than Max or lesser than Min is called an outlier.
# * approximately 95% or the data are expected to lie between the inner fences

# %%
#Diragrama de cajas
_high = np.random.rand(20) + 0.5
center = np.random.rand(20)
_low = np.random.rand(20) - 0.5

data = [_high,center,_low]
plt.boxplot(data,notch=True, vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x10f84d3f2e0>,
#   <matplotlib.lines.Line2D at 0x10f84d3f5b0>,
#   <matplotlib.lines.Line2D at 0x10f84d48a00>,
#   <matplotlib.lines.Line2D at 0x10f84d48dc0>,
#   <matplotlib.lines.Line2D at 0x10f84d63250>,
#   <matplotlib.lines.Line2D at 0x10f84d635e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x10f84d3f940>,
#   <matplotlib.lines.Line2D at 0x10f84d3fcd0>,
#   <matplotlib.lines.Line2D at 0x10f84d57190>,
#   <matplotlib.lines.Line2D at 0x10f84d57520>,
#   <matplotlib.lines.Line2D at 0x10f84d63970>,
#   <matplotlib.lines.Line2D at 0x10f84d63d00>],
#  'boxes': [<matplotlib.patches.PathPatch at 0x10f84d2ee20>,
#   <matplotlib.patches.PathPatch at 0x10f84d48610>,
#   <matplotlib.patches.PathPatch at 0x10f84d57e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x10f84d480a0>,
#   <matplotlib.lines.Line2D at 0x10f84d578b0>,
#   <matplotlib.lines.Line2D at 0x10f84d6d0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x10f84d48430>,
#   <matplotlib.lines.Line2D at 0x10f84d57c40>,
#   <matplotlib.lines.Line2D at 0x10f84d6d460>],
#  'means': []}

# %% [markdown]
# ## <u>Violin Plot:</u>

# %%
#Diagrama de violin, se lee de la misma manera que el de cajas
plt.figure(figsize=(9,4))
plt.violinplot(data,widths=0.40, vert=True, showmeans=True, showextrema=True, showmedians=True)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x10f84dd4160>,
#   <matplotlib.collections.PolyCollection at 0x10f84dd4550>,
#   <matplotlib.collections.PolyCollection at 0x10f84dd4880>],
#  'cmeans': <matplotlib.collections.LineCollection at 0x10f84d20190>,
#  'cmaxes': <matplotlib.collections.LineCollection at 0x10f84dd4e20>,
#  'cmins': <matplotlib.collections.LineCollection at 0x10f84ded1f0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x10f84ded580>,
#  'cmedians': <matplotlib.collections.LineCollection at 0x10f84ded910>}

# %%
#Diagrama de violin con labels
fig, axes = plt.subplots(figsize=(9, 4))
axes.violinplot(data, widths=0.40, vert=True, showmeans=True, showextrema=True, showmedians=True)
axes.set_title('Violinplot', fontsize=15)
plt.setp(axes, xticks=[i+1 for i in range(len(data))], xticklabels=['high','center','low'])
# Out:
# [<matplotlib.axis.XTick at 0x10f84eaafd0>,
#  <matplotlib.axis.XTick at 0x10f84eaafa0>,
#  <matplotlib.axis.XTick at 0x10f84eaa670>,
#  Text(1, 0, 'high'),
#  Text(2, 0, 'center'),
#  Text(3, 0, 'low')]

# %% [markdown]
# ## <u>Bubble Charts:</u>

# %%
#Burbujas
plt.style.use('ggplot')
df = pd.DataFrame(np.random.rand(50, 3), columns=['x','y','z'])
df.plot(kind='scatter',x='x',y='y',s=df['z']*400, color='red', edgecolors='black')
# s is the size of the bubble
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# ## <u>3D Plots:</u>

# %%
#Graficas en 3d con la libreria Axes3d
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
#Grafica 3d
img = plt.figure()
ax = Axes3D(img)
x = np.arange(-5,5,0.25)
y = np.arange(-5,5,0.25)
X, Y = np.meshgrid(x, y)
V = np.sqrt(X**2 + Y**2)
Z = np.sin(V)
ax.plot_surface(X,Y,Z, rstride=2, cstride=2, cmap='hot',linewidth=0)
# Out:
# C:\Users\julio\AppData\Local\Temp/ipykernel_13880/843725370.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(img)

# %% [markdown]
# #### Color bar:

# %%
#Barra de color
p = ax.plot_surface(X,Y,Z, rstride=1, cstride=1, cmap='hot',linewidth=0)
img.colorbar(p, shrink=0.5)
img
# The rstride and cstride parameters help in sizing the cell on the surface.

# %% [markdown]
# #### Setting the view angle:

# %%
#Cambiar angulo
fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(elev=0., azim=0)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')
# Out:
# C:\Users\julio\AppData\Local\Temp/ipykernel_13880/1709475027.py:3: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
# setting the view at 50 degrees elevation and 30 degrees angle:
fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(elev=50., azim=30)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %% [markdown]
# ## 3D Line Plot:

# %%
#Linea en 3d
fig = plt.figure(figsize=(8,6))
ax = fig.gca(projection='3d')

v = np.linspace(-5 * np.pi, 5 * np.pi, 100)
z = np.linspace(-3, 3, 100)
r = z**2 + 1
x = r * np.sin(v)
y = r * np.cos(v)
 
ax.plot(x, y, z, label='3D curve')
ax.legend(loc='best')

# %% [markdown]
# ## Reference:
#
# https://matplotlib.org/2.0.1/examples/statistics/index.html
